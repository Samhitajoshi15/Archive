# %%
# Questions

quest_1 = "What is 2 + 2 ?"
quest_2 = "What is 12 x 12 ?"
quest_3 = "Which of these numbers is divisble by 13 ?"
quest_4 = "Which of These is a prime number ?"
quest_5 = "What is 64/8 ?"


# Choices for Answers

c1 = [2, 144, 2, 10, 8 ]
c2 = [4, 36, 16, 6, 16 ]
c3 = [5, 169, 4, 13, 2]
c4 = [22, 25, 39, 4, 32]


# Initial Score

score = 0


# Question 1

print(f"Q1---> {quest_1}")
print(f"Options : (a){c1[0]} (b){c2[0]} (c){c3[0]} (d){c4[0]}")


answer = int(input("Enter Your Choice : "))

if answer == c1[0]:
    print(f"Wrong Answer! It\'s Not {c1[0]}\n")
    print(f"Score is {score}")
elif answer == c2[0]:
    print(f"Yes The Correct Answer is {c2[0]}\n")
    score += 10
    print(f"Score is now {score}")
elif answer == c3[0]:
    print(f"Wrong Answer! It\'s Not {c3[0]}\n")
    print(f"Score is {score}")
elif answer == c4[0]:
    print(f"Wrong Answer! It\'s Not {c4[0]}\n")
    print(f"Score is {score}")
else:
    print("Invalid Input!!!Try Again with a valid Input\n")
    print(f"Score is {score}")

print("===="*10)
print("========== Next Question is : ==========")
print("===="*10 + "\n")


# Question 2

print(f"Q2---> {quest_2}")
print(f"Options : (a){c1[1]} (b){c2[1]} (c){c3[1]} (d){c4[1]}")

answer = int(input("Enter Your Choice : "))

if answer == c1[1]:
    print(f"Yes The Correct Answer is {c1[1]}\n")
    score += 10
    print(f"Score is now {score}")
elif answer == c2[1]:
    print(f"Wrong Answer! It\'s Not {c2[1]}\n")
    score -= 5
    print(f"Score is now {score}")
elif answer == c3[1]:
    print(f"Wrong Answer! It\'s Not {c3[1]}\n")
    score -= 5
    print(f"Score is now {score}")
elif answer == c4[1]:
    print(f"Wrong Answer! It\'s Not {c4[1]}\n")
    score -= 5
    print(f"Score is now {score}")
else:
    print("Invalid Input!!!Try Again with a valid Input\n")
    score -= 2
    print(f"Score is now {score}" + "\n")

print("===="*10)
print("========== Next Question is : ==========")
print("===="*10 + "\n")

# Question 3

print(f"Q3---> {quest_3}")
print(f"Options : (a){c1[2]} (b){c2[2]} (c){c3[2]} (d){c4[2]}")

answer = int(input("Enter Your Choice : "))

if answer == c1[2]:
    print(f"Wrong Answer! It\'s Not {c1[2]}\n")
    score -= 5
    print(f"Score is now {score}")
elif answer == c2[2]:
    print(f"Wrong Answer! It\'s Not {c2[2]}\n")
    score -= 5
    print(f"Score is now {score}")
elif answer == c3[2]:
    print(f"Wrong Answer! It\'s Not {c3[2]}\n")
    score -= 5
    print(f"Score is now {score}")
elif answer == c4[2]:
    print(f"Yes the Correct Answer is {c4[2]}\n")
    score += 10
    print(f"Score is now {score}")
else:
    print("Invalid Input!!!Try Again with a valid Input\n")
    score -= 2
    print(f"Score is now {score}" + "\n")

print("===="*10)
print("========== Next Question is : ==========")
print("===="*10 + "\n")

# Question 4

print(f"Q4---> {quest_4}")
print(f"Options : (a){c1[3]} (b){c2[3]} (c){c3[3]} (d){c4[3]}")

answer = int(input("Enter Your Choice : "))

if answer == c1[3]:
    print(f"Wrong Answer! It\'s Not {c1[3]}\n")
    score -= 5
    print(f"Score is now {score}")
elif answer == c2[3]:
    print(f"Wrong Answer! It\'s Not {c2[3]}\n")
    score -= 5
    print(f"Score is now {score}")
elif answer == c3[3]:
    print(f"Yes the Correct Answer is {c3[3]}\n")
    score += 10
    print(f"Score is now {score}")
elif answer == c4[3]:
    print(f"Wrong Answer! It\'s Not {c4[3]}\n")
    score -= 5
    print(f"Score is now {score}")
else:
    print("Invalid Input!!!Try Again with a valid Input\n")
    score -= 2
    print(f"Score is now {score}" + "\n")

print("===="*10)
print("========== Next Question is : ==========")
print("===="*10 + "\n")

#Question 5

print(f"Q5---> {quest_5}")
print(f"Options : (a){c1[4]} (b){c2[4]} (c){c3[4]} (d){c4[4]}")


answer = int(input("Enter Your Choice : "))

if answer == c1[4]:
    print(f"Yes The Correct Answer is {c1[4]}\n")
    score += 10
    print(f"Score is now {score}")
elif answer == c2[4]:
    print(f"Wrong Answer! It\'s Not {c2[4]}\n")
    score -= 5
    print(f"Score is now {score}")
elif answer== c3[4]:
    print(f"Wrong Answer! It\'s Not {c3[4]}\n")
    score -= 5
    print(f"Score is now {score}")
elif answer == c4[4]:
    print(f"Wrong Answer! It\'s Not {c4[4]}\n")
    score -= 5
    print(f"Score is now {score}")
else:
    print("Invalid Input!!!Try Again with a valid Input\n")
    score -= 2
    print(f"Score is now {score}")


# Printing th Final Score

print("===="*10)
print(f"======= Your Final Score is : {score} =======")
print("===="*10)


# Publishing Rank
if score < 0:
    print(" Your Rank : Loser")
elif score >= 0 and score <= 10:
    print("Your Rank :  Noob")
elif score > 10 and score <= 20:
    print("Your Rank : Rookie")
elif score > 20 and score <= 30:
    print("Your Rank : Pro")
elif score > 30 and score <= 40:
    print("Your Rank : Legend")
elif score > 40 and score <= 50:
    print("Your Rank : Ultimate God")
print("========================================")


#Program Completed
# Out:
# Q1---> What is 2 + 2 ?
# Options : (a)2 (b)4 (c)5 (d)22
